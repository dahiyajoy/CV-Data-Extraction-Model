# %% [markdown]
# <a href="https://colab.research.google.com/github/dahiyajoy/Resume-Extraction-Model/blob/Master/PyresParser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extracting Data from Resume**

# %%
# !pip install aiohttp==3.8.2
# !pip install yarl==1.8.1
# !pip install frozenlist==1.3.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 7.5 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'aiohttp' candidate (version 3.8.2 at https://files.pythonhosted.org/packages/8f/52/ea1e5eac3e748a94fdaafba5ab68adfb833f0cbdb68cc8149fbba5574176/aiohttp-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/aiohttp/) (requires-python:>=3.6))
# Reason for being yanked: This version includes overly restrictive multidict upper boundary disallowing multidict v6+. The previous patch version didn't have that and this is now causing dependency resolution problems for the users who have an "incompatible" version pinned. This is not really necessary anymore and will be addressed in the next release v3.8.3
#
# https://github.com/aio-libs/aiohttp/pull/6950
# ...
#   Attempting uninstall: multidict
# ...

# %%
# !pip install nltk
# !pip install spacy
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# !pip install pyresparser
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 77.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.2/369.2 kB 24.5 MB/s eta 0:00:00
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047086 sha256=9ea78cfbb1e7f8d115ee353cba9e29809302ac1666be12eac6defd00c009b465
#   Stored in directory: /root/.cache/pip/wheels/4f/1f/0e/16fae4b01d2d87454e0f484e58c48793efcf237f0894c1c4bd
# Successfully built en-core-web-sm
# ...
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
# ...

# %%
import nltk
nltk.download('stopwords')
from pyresparser import ResumeParser
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import os

path = '/content/Resumes'
parsed_resumes = []

with os.scandir(path) as myFolder:
    for myFile in myFolder:
        if myFile.name.endswith(".pdf") and myFile.is_file():
            file_path = os.path.join(path, myFile.name)
            data = ResumeParser(file_path).get_extracted_data()
            parsed_resumes.append(data)


data
# Out:
# {'name': 'n e',
#  'email': 'indhujan17@gmail.com',
#  'mobile_number': '800 2218',
#  'skills': ['Windows',
#   'Coding',
#   'Ui',
#   'Ansible',
#   'Training',
#   'Strong analytical skills',
#   'Cloud',
#   'Architecture',
#   'Mysql',
#   'Css',
#   'English',
#   'Analytical',
#   'Json',
#   'Continuous improvement',
#   'Agile',
#   'R',
#   'Java',
#   'System',
#   'Analytics',
#   'Improvement',
#   'Database',
#   'Aws',
#   'Sql',
#   'Rest',
#   'Scrum',
#   'Mathematics',
#   'Jira',
#   'Xml',
#   'Hbase',
#   'C',
#   'Api',
#   'Testing',
#   'Html',
#   'P'],
#  'college_name': None,
#  'degree': None,
#  'designation': ['Software Developer',
#   'Discover-SRC NAART POD',
#   'Programmer Analyst'],
#  'experience': ['maintaining enterprise-level applications. Expertise in Java, SpringBoot',
#   'Framework, Microservices architecture, REST API and SQL databases. Strong'],
#  'company_names': None,
#  'no_of_pages': 1,
#  'total_experience': 0.0}

# %% [markdown]
# # **Writing to Excel**

# %%
import pandas as pd


# List to hold the final structured data
final_data_list = []

# Structure the parsed data
for resume_data in parsed_resumes:
    data_final = {
        "Name": resume_data["name"],
        "Email": resume_data["email"],
        "Mobile Number": resume_data["mobile_number"],
        "Skills": ", ".join(resume_data["skills"]) if resume_data["skills"] else "",
        "College Name": ", ".join(resume_data["college_name"]) if resume_data["college_name"] else "",
        "Degree": ", ".join(resume_data["degree"]) if resume_data["degree"] else "",
        "Designation": ", ".join(resume_data["designation"]) if resume_data["designation"] else "",
        "Company Names": ", ".join(resume_data["company_names"]) if resume_data["company_names"] else "",
        "Total Experience": resume_data["total_experience"]
    }
    final_data_list.append(data_final)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(final_data_list)

# Add a "Number" column starting from 1
df.insert(0, 'S. No.', range(1, len(df) + 1))

# Save the DataFrame to an Excel file
df.to_excel('/content/Resume_Data.xlsx', index=False)

# Read and print the data from the Excel file
pd.read_excel('/content/Resume_Data.xlsx')
# Out:
#    S. No.                       Name  \
# 0       1  GULAMHUSAIN +918511320034
# 1       2      Ravi Ranjah Choudhary
# 2       3                        NaN
# 3       4              Trupti Pandit
# 4       5            Khushboo Bharti
# 5       6                        i s
# 6       7              Madhan Bangre
# 7       8           Technical Skills
# 8       9                        n e
#
#                                                Email Mobile Number  \
# 0                            gulamhusain83@gmail.com    9185113200
# 1                                ravidbg28@gmail.com    8873585454
# 2  SatyaKiranKoduru+917337255891Kiran20999@gmai...    9173372558
# 3                      truptichaitanya8888@gmail.com    8975470858
# 4                        khushboobharti342@gmail.com    7408775477
# 5                             komalharad26@gmail.com    9209633379
# 6                          madhanbangre970@gmail.com    7892447654
# ...
