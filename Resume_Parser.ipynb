# %% [markdown]
# <a href="https://colab.research.google.com/github/dahiyajoy/Resume-Extraction-Model/blob/Master/Resume_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extracting Data from Resume**

# %%
# !pip install resume-parser

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 93.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install spacy

# %%
from resume_parser import resumeparse
import nltk
nltk.download('stopwords')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.9). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import os

path = '/content/Resumes'
parsed_resumes = []

with os.scandir(path) as myFolder:
    for myFile in myFolder:
        if myFile.name.endswith(".pdf") and myFile.is_file():
            file_path = os.path.join(path, myFile.name)
            data = resumeparse.read_file(file_path)
            parsed_resumes.append(data)

# %%
import pandas as pd


# List to hold the final structured data
final_data_list = []

# Structure the parsed data
for resume_data in parsed_resumes:
    data_final = {
        "Name": resume_data["name"],
        "Email": resume_data["email"],
        "Mobile Number": resume_data["phone"],
        "Skills": ", ".join(resume_data["skills"]) if resume_data["skills"] else "",
        "College Name": ", ".join(resume_data["university"]) if resume_data["university"] else "",
        "Degree": ", ".join(resume_data["degree"]) if resume_data["degree"] else "",
        "Designation": ", ".join(resume_data["designition"]) if resume_data["designition"] else "",
        "Company Names": ", ".join(resume_data["Companies worked at"]) if resume_data["Companies worked at"] else "",
        "Total Experience": resume_data["total_exp"]
    }
    final_data_list.append(data_final)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(final_data_list)

# Add a "Number" column starting from 1
df.insert(0, 'S. No.', range(1, len(df) + 1))

# Save the DataFrame to an Excel file
df.to_excel('/content/Resume_Data.xlsx', index=False)

# Read and print the data from the Excel file
pd.read_excel('/content/Resume_Data.xlsx')
# Out:
#    S. No.                       Name                          Email  \
# 0       1              Trupti Pandit  truptichaitanya8888@gmail.com
# 1       2                        s s         komalharad26@gmail.com
# 2       3  GULAMHUSAIN +918511320034        gulamhusain83@gmail.com
# 3       4                        NaN         praveenvs777@gmail.com
# 4       5                 Tamil Nadu           indhujan17@gmail.com
# 5       6                        NaN           Kiran20999@gmail.com
# 6       7            Khushboo Bharti    khushboobharti342@gmail.com
# 7       8           India Ranganatha      rangudevang1997@gmail.com
# 8       9                Ravi Ranjah            ravidbg28@gmail.com
# 9      10              Madhan Bangre      madhanbangre970@gmail.com
#
#      Mobile Number                                             Skills  \
# 0  +91- 8975470858  :, Database: MySQL,  SQL Database,  PostgreSQL...
# 1       9209633379  kafka, o, pdf, user requirements, typescript, ...
# ...

# %% [markdown]
# # **Writing to Excel**

# %%
import pandas as pd

# Convert the dictionary to a Pandas DataFrame
df = pd.DataFrame([data_final])

# Save the DataFrame to an Excel file
df.to_excel('/content/Resume_Data.xlsx', index=False)

pd.read_excel('/content/Resume_Data.xlsx')
# Out:
#             Name                      Email  Mobile Number  \
# 0  Madhan Bangre  madhanbangre970@gmail.com     7892447654
#
#                                               Skills College Name Degree  \
# 0  ['Akka Framework', ' PostgreSQL', 'Tools Intel...           []     []
#
#                                 Designation Company Names  Total Experience
# 0  ['java developer', 'software developer']            []                 3
